# %% [markdown]
# <a href="https://colab.research.google.com/github/mashrur100/SIMULATION_LAB_3/blob/main/Mashrur_Zawad_1074.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from sympy import Matrix
import matplotlib.pyplot as plt
import seaborn as sns

# Generate 100,000 random numbers in [0,1)
random_numbers = np.random.rand(10)

# Plot the histogram
plt.hist(random_numbers, bins=50,  alpha=0.5, color='blue', edgecolor='black')

# Labels and title
plt.xlabel('Value')
plt.ylabel('Density')
plt.title('Histogram of Uniformly Distributed Random Numbers')
plt.grid(True)

# Show the plot
plt.show()

# Generate 10,000 random values from a normal distribution with mean=100 and std=10
NormalValues = np.random.normal(0, 1, 500)

# Create a histogram
plt.hist(NormalValues, bins=30, edgecolor='black')
plt.title('Histogram of Normal Distribution (mean=100, std=10)')
plt.xlabel('Value')
plt.ylabel('Frequency')
plt.show()

# With Seed
np.random.seed(4)  # Setting seed to 10
seeded_matrix = np.random.randint(1, 50, (3, 3))
print("Seeded Random Matrix:\n", seeded_matrix)

# Without Seed
np.random.seed(None)  # No seed, generates different values each time
non_seeded_matrix = np.random.randint(1, 50, (3, 3))
print("\nNon-Seeded Random Matrix:\n", non_seeded_matrix)
# Out:
# Seeded Random Matrix:
#  [[47  6  2]
#  [41 24  9]
#  [10 40 46]]
#
# Non-Seeded Random Matrix:
#  [[42 33 15]
#  [ 5 10 33]
#  [40 43 39]]
